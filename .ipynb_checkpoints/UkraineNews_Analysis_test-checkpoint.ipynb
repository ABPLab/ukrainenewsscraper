# %% [markdown]
# # Ukraine war news analysis

# %%
import os
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import datetime
import matplotlib.pyplot as plt
from scipy import stats
import scipy
# from dtaidistance import dtw
import pyeasytrend

# %%
#Days of interest. Change the range here to study only a certain amount of time (e.g. 1 month)
firstDay = '2022-02-24'
lastDay = '2022-03-24'

KEYWORDS = ['bambino','bambina','bambini','neonati','neonata','neonato','child','children','infants', 'toddler', 'toddlers','infant','kid','kids']
KEYWORDSADULTS = ['uomo','donna','uomini','man','woman','men','women']

# %%
url = '/home/giulio/Repositories/ukrainenewsscraper/Processed/db.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Wsj: "Ue ha proposto di sanzionare anche le fi...
# 1           1  Usa sanzionano Hydra, maggiore piattaforma del...
# 2           2  Casa Bianca: nuove sanzioni a dirigenti govern...
# 3           3  Bucha, la Russia si difende dalle accuse | In ...
# 4           4         Esplosioni udite nella regione di Leopoli
#
#                                                  url                 Date  \
# 0  https://www.tgcom24.mediaset.it//temporeale/te...  2022-04-05 23:19:00
# 1  https://www.tgcom24.mediaset.it//temporeale/te...  2022-04-05 23:01:00
# 2  https://www.tgcom24.mediaset.it//temporeale/te...  2022-04-05 22:42:00
# 3  https://www.tgcom24.mediaset.it/mondo/ucraina-...  2022-04-05 22:20:26
# 4  https://www.tgcom24.mediaset.it//temporeale/te...  2022-04-05 22:20:00
#
#                                              Article   Source ID Language
# ...

# %%
url = '/home/giulio/Repositories/ukrainenewsscraper/Processed/dbCasualties.csv'
dfCasualties = pd.read_csv(url)
dfCasualties.head()
#TODO Clean text in 02/26. check if growth is linear/cubic/quadratic, if so may be wort trying reconstring missing data points
#TODO Can we import pyeasytrends in colab?
# Out:
#          Day  totalDeaths  AdultsDeaths  ChildrenDeaths  total injured  \
# 0  2/24/2022          NaN           NaN             NaN            NaN
# 1  2/25/2022          NaN           NaN             NaN            NaN
# 2  2/26/2022          NaN           NaN             NaN            NaN
# 3  2/27/2022        102.0          95.0             7.0          304.0
# 4  2/28/2022         40.0          34.0             6.0          104.0
#
#    adults injured  children injured  totalEvacuee  AdultsEvacuee  \
# 0             NaN               NaN       79034.0            NaN
# 1             NaN               NaN      115157.0            NaN
# 2             NaN               NaN      150472.0            NaN
# 3           283.0              21.0      171080.0            NaN
# 4            99.0               5.0      156771.0            NaN
#
#    ChildrenEvacuee  ItalyTotalRefugees  ItalyAdultsRefugess  \
# 0              NaN                 NaN                  NaN
# ...

# %% [markdown]
# # Data reconstruction
#
# The dataset as miss

# %%
totalDeaths = dfCasualties.loc[4:].totalDeaths.astype(int).to_list()
childrenDeaths = dfCasualties.loc[4:].ChildrenDeaths.astype(int).to_list()

dates = list(range(0, len(totalDeaths)))

# https://github.com/Gabrock94/pyEasyTrend
results = pyeasytrend.analyzeTrend(dates, totalDeaths, maxDegree=3, visualize=True)
pyeasytrend.tablifyResults(results)
# Out:
#    Order        R2           SSE         F    pvalue         AIC         BIC
# 0      1  0.058775  10191.589133  1.561118  0.223073  238.826673  240.122510
# 1      2  0.077336   9990.602383  0.482822  0.493820  240.288890  242.880564
# 2      3  0.144440   9264.008415  1.803934  0.192342  240.250172  244.137683

# %%
totalDeaths = dfCasualties.loc[4:].AdultsDeaths.astype(int).to_list()

# %% [markdown]
# # Data do not follow a specific model. Avoid reconstruction

# %%
#time period to study
df = df[(pd.to_datetime(df.Date) > pd.to_datetime(firstDay)) & (pd.to_datetime(df.Date) < pd.to_datetime(lastDay))]
print(len(df), 'Valid articles in selected dates range')
# Out:
# 3421 Valid articles in selected dates range

# %%
#How many articles per source?
df.Source.value_counts().plot.bar()
df.Source.value_counts()
# Out:
# TGCOM24    2255
# Open        660
# cna         462
# ilpost       44
# Name: Source, dtype: int64

# %%
#How many articles per language?
df.Language.value_counts().plot.bar()
df.Language.value_counts()
# Out:
# it    2959
# en     462
# Name: Language, dtype: int64

# %%
datecount = pd.DataFrame(pd.to_datetime(df['Date']).dt.date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
plt.plot(datecount.Date, datecount.Count, label='Total number of articles')
plt.plot(datecount.Date[4:], totalDeaths[:-3], label='Adults')
plt.plot(datecount.Date[4:], childrenDeaths[:-3], label='Children')
plt.xticks(rotation=-90)
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.title('Number of articles by day')
plt.legend()

# %%
#Create a date only field, move datetime to datetime field
df = df.assign(Datetime = df.Date)
df.Date = pd.to_datetime(df['Date']).dt.date

# %%
#see the number of articles by source
for source in df.Source.unique():
    t = pd.DataFrame(df[df.Source == source].Date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
    plt.plot(t.Date, t.Count, label=source)
    
plt.xticks(rotation=-90)
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.title('Number of articles by day')
plt.legend()

# %%
# Rapid Analysis:

df = df.assign(hasKeyword = [any([keyword in str(article) for keyword in KEYWORDS]) for article in df.Article])
df.hasKeyword.value_counts()

df = df.assign(hasKeywordAdult = [any([keyword in str(article) for keyword in KEYWORDSADULTS]) for article in df.Article])
df.hasKeyword.value_counts()
# Out:
# False    3091
# True      330
# Name: hasKeyword, dtype: int64

# %%
#same plot as above but only for articles with keywords
plt.figure(figsize=(10,6))
ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
datecount = pd.DataFrame(pd.to_datetime(df[df.hasKeyword == True]['Date']).dt.date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
datecount2 = pd.DataFrame(pd.to_datetime(df['Date']).dt.date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
plt.plot(datecount.Date, datecount.Count / datecount2.Count * 100, label='Articles')
datecountAdults = pd.DataFrame(pd.to_datetime(df[df.hasKeywordAdult == True]['Date']).dt.date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
plt.plot(datecount.Date[4:], totalDeaths[:-3], label='Adults')
plt.plot(datecount.Date, datecountAdults.Count / datecount2.Count * 100, label='Articles Adults')
plt.plot(datecount.Date[4:], childrenDeaths[:-3], label='Children')
plt.xticks(rotation=-90)
plt.xlabel('Date', fontsize='x-large')
plt.ylabel('Number of Articles', fontsize='x-large')
plt.title('Number of articles contaning keyword by day', weight='bold', fontsize='xx-large')
plt.legend(bbox_to_anchor=(1,1), loc="upper left")

# %%
stats.ttest_rel(totalDeaths[:-3] / (datecountAdults.Count / datecount2.Count * 100)[4:], childrenDeaths[:-3] / (datecount.Count / datecount2.Count * 100)[4:])
print(list(totalDeaths[:-3] / (datecountAdults.Count / datecount2.Count * 100)[4:]), list(childrenDeaths[:-3] / (datecount.Count / datecount2.Count * 100)[4:]))
# Out:
# [0.4799999999999999, 1.1216216216216217, 0.2627118644067797, 1.098989898989899, 0.22878504672897196, 0.4, 0.9944927536231885, 0.16838095238095238, 0.4115789473684211, 0.39311111111111113, 0.2176829268292683, 0.16174757281553398, 0.2118918918918919, 0.5072580645161291, 0.6822988505747126, 0.3985714285714285, 0.6042352941176471, 0.4439024390243903, 0.3157142857142857, 0.5403508771929825, 0.2875, 0.3310810810810811, 0.2683333333333333, 0.6049382716049383] [0.9163636363636363, 0.17647058823529413, 0.17222222222222222, 0.4533333333333333, 0.432, 0.31199999999999994, 0.26857142857142857, 0.1942857142857143, 0.5519999999999999, 0.32533333333333336, 0.0, 0.10818181818181817, 0.07, 0.425, 0.20363636363636364, 0.4800000000000001, 0.40125000000000005, 0.05777777777777778, 0.3269230769230769, 0.77, 0.0, 0.32666666666666666, 0.39428571428571424, 0.8181818181818182]

# %%
plt.plot((datecountAdults.Count / datecount2.Count * 100)[4:] / totalDeaths[:-3])
plt.plot((datecount.Count / datecount2.Count * 100)[4:] / childrenDeaths[:-3])

# %%
a = (datecountAdults.Count / datecount2.Count * 100)[4:] / totalDeaths[:-3]
b = (datecount.Count / datecount2.Count * 100)[4:] / childrenDeaths[:-3]
b = pd.Series([x for  x in b if x != np.inf])
a.mean(), a.std(), b.mean(), b.std(), len(a), len(b), stats.pearsonr(a[:-2], b)
# Out:
# (2.863584902683547,
#  1.4847339785247262,
#  4.449979518063006,
#  4.155180071388707,
#  24,
#  22,
#  (0.24822551541396326, 0.26533695256879203))

# %%
stats.pearsonr(totalDeaths[:-3], childrenDeaths[:-3])
# Out:
# (0.16813128751418618, 0.4322683552611932)

# %%
stats.pearsonr(datecount.Count[4:], totalDeaths[:-3])
# Out:
# (-0.208918436575474, 0.32722565063171405)

# %%
a = (datecount.Count[4:] / datecount2.Count[4:] * 100).astype(int)
b = childrenDeaths[:-3]

# pd.DataFrame(data= np.transpose([a,b]), columns=['Articoli','Morti']).corr()
d = dtw.distance_fast(np.array(a, dtype=np.double),np.array(b, dtype=np.double))
print(d)

a = (datecountAdults.Count[4:] / datecount2.Count[4:] * 100).astype(int)
b = totalDeaths[:-3]

# pd.DataFrame(data= np.transpose([a,b]), columns=['Articoli','Morti']).corr()
d = dtw.distance_fast(np.array(a, dtype=np.double),np.array(b, dtype=np.double))
print(d)
# Out:
# 21.517434791350013
# 213.0211257129208

# %%
b
# Out:
# [34,
#  83,
#  20,
#  80,
#  17,
#  30,
#  73,
#  13,
#  34,
#  29,
#  15,
#  14,
#  16,
#  37,
#  53,
#  31,
#  48,
#  35,
#  26,
#  44,
#  23,
#  25,
#  21,
#  49]

# %%
#see the number of articles by source
plt.figure(figsize=(20,10))
for source in df.Source.unique()[:-1]:
    t = pd.DataFrame(df[(df.Source == source) & (df.hasKeyword)].Date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
    plt.plot(t.Date, t.Count, label=source)
    
plt.xticks(rotation=-90)
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.title('Number of articles with keyword by day')

plt.plot(datecount.Date[4:], childrenDeaths[:-3], label='Children')
plt.legend()

# %%
#see the number of articles by source
plt.figure(figsize=(20,10))
for source in df.Source.unique()[:-1]:
    t = pd.DataFrame(df[(df.Source == source) & (df.hasKeywordAdult)].Date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()

    cf = pd.DataFrame(df[(df.Source == source)].Date.value_counts()).rename({'Date':'Count'}, axis=1).rename_axis('Date').sort_values(by='Date').reset_index()
    plt.plot(t.Date, t.Count, label=source)
    
plt.xticks(rotation=-90)
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.title('Number of articles with keyword by day')

plt.plot(datecount.Date[4:], totalDeaths[:-3], label='Total Death')
plt.legend()
